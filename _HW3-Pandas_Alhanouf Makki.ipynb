# %% [markdown]
# # Assigment 3

# %% [markdown]
# ### Name: Alhanouf Saud Makki
# ### ID: 431000020

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Part 1

# %% [markdown]
# Consider the following Python dictionary data and Python list labels:

# %%
data = {'author': ['Ahmad', 'Ahmad', 'Majed', 'Sami', 'Ahmad', 'Ahmad', 'Majed', 'Ahmad', 'Sami', 'Sami'],
        'impact_factor': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'downloads': [3, 13, 2, 3, 5, 3, 7, 1, 24, 4],
        'type': ['journal', 'journal', 'conference', 'journal', 'conference', 'conference', 'conference', 'journal', 'conference', 'conference']}

# %% [markdown]
# 1- Create a DataFrame df from this dictionary data above

# %%
df = pd.DataFrame(data)
df
# Out:
#   author  impact_factor  downloads        type
# 0  Ahmad            2.5          3     journal
# 1  Ahmad            3.0         13     journal
# 2  Majed            0.5          2  conference
# 3   Sami            NaN          3     journal
# 4  Ahmad            5.0          5  conference
# 5  Ahmad            2.0          3  conference
# 6  Majed            4.5          7  conference
# 7  Ahmad            NaN          1     journal
# 8   Sami            7.0         24  conference
# 9   Sami            3.0          4  conference

# %% [markdown]
# 2-
# - Run basic calculations to obtain number of unique authors.
#
# - Display the summary data frame

# %%
df.groupby('author').describe()
# Out:
#        impact_factor                                              downloads  \
#                count   mean       std  min    25%   50%  75%  max     count
# author
# Ahmad            4.0  3.125  1.314978  2.0  2.375  2.75  3.5  5.0       5.0
# Majed            2.0  2.500  2.828427  0.5  1.500  2.50  3.5  4.5       2.0
# Sami             2.0  5.000  2.828427  3.0  4.000  5.00  6.0  7.0       3.0
#
#
#              mean        std  min   25%  50%    75%   max
# author
# Ahmad    5.000000   4.690416  1.0  3.00  3.0   5.00  13.0
# Majed    4.500000   3.535534  2.0  3.25  4.5   5.75   7.0
# Sami    10.333333  11.846237  3.0  3.50  4.0  14.00  24.0

# %%
df.describe()
# Out:
#        impact_factor  downloads
# count       8.000000  10.000000
# mean        3.437500   6.500000
# std         2.007797   7.027723
# min         0.500000   1.000000
# 25%         2.375000   3.000000
# 50%         3.000000   3.500000
# 75%         4.625000   6.500000
# max         7.000000  24.000000

# %% [markdown]
# 3- Return the first 4 rows of the DataFrame df.

# %%
df.head(4)
# Out:
#   author  impact_factor  downloads        type
# 0  Ahmad            2.5          3     journal
# 1  Ahmad            3.0         13     journal
# 2  Majed            0.5          2  conference
# 3   Sami            NaN          3     journal

# %% [markdown]
# 4- Select just the 'author' and 'impact_factor' columns from the DataFrame df.

# %%
df[['author','impact_factor']]
# Out:
#   author  impact_factor
# 0  Ahmad            2.5
# 1  Ahmad            3.0
# 2  Majed            0.5
# 3   Sami            NaN
# 4  Ahmad            5.0
# 5  Ahmad            2.0
# 6  Majed            4.5
# 7  Ahmad            NaN
# 8   Sami            7.0
# 9   Sami            3.0

# %% [markdown]
# 5- Select the data in rows [2, 4, 7] and in columns ['author', 'impact_factor'].

# %%
df.loc[[2,4,7],['author','impact_factor']]
# Out:
#   author  impact_factor
# 2  Majed            0.5
# 4  Ahmad            5.0
# 7  Ahmad            NaN

# %% [markdown]
# 6- Select only the rows where the number of downloads is greater than 5.

# %%
df[df.loc[:,'downloads']>5]
# Out:
#   author  impact_factor  downloads        type
# 1  Ahmad            3.0         13     journal
# 6  Majed            4.5          7  conference
# 8   Sami            7.0         24  conference

# %% [markdown]
# 7- Select the rows where the impact_factor is missing, i.e. it is NaN.

# %%
df[df.loc[:,'impact_factor'].isnull()]
# Out:
#   author  impact_factor  downloads     type
# 3   Sami            NaN          3  journal
# 7  Ahmad            NaN          1  journal

# %% [markdown]
# 8- Select the rows where the author is a Ahmad and the downloads is less than 4.

# %%
df[(df.loc[:,'author']=='Ahmad') & (df.loc[:,'downloads']<4)]
# Out:
#   author  impact_factor  downloads        type
# 0  Ahmad            2.5          3     journal
# 5  Ahmad            2.0          3  conference
# 7  Ahmad            NaN          1     journal

# %% [markdown]
# 9- Select the rows the downloads is between 2 and 5 (hint: read about between function)

# %%
df[df.loc[:,'downloads'].between(2,5)]
# Out:
#   author  impact_factor  downloads        type
# 0  Ahmad            2.5          3     journal
# 2  Majed            0.5          2  conference
# 3   Sami            NaN          3     journal
# 4  Ahmad            5.0          5  conference
# 5  Ahmad            2.0          3  conference
# 9   Sami            3.0          4  conference

# %% [markdown]
#  10- Calculate the sum of all downloads in df (i.e. the total number of downloads).

# %%
print(sum(df.loc[:,'downloads']))
# Out:
# 65

# %% [markdown]
# 11- Calculate the mean downloads for each different author in df.

# %%
df.groupby('author')['downloads'].mean().reset_index(name='mean')
# Out:
#   author       mean
# 0  Ahmad   5.000000
# 1  Majed   4.500000
# 2   Sami  10.333333

# %% [markdown]
# 12-  Count the number of each type of paper (journal or conference) in df.

# %%
number_type=df.type.value_counts()
number_type
# Out:
# conference    6
# journal       4
# Name: type, dtype: int64

# %% [markdown]
# 13- Plot a bar chart with the different authors.

# %%
df.groupby('author')['downloads'].count().plot(x="author", kind="bar")
# Out:
# <AxesSubplot:xlabel='author'>

# %% [markdown]
# 14- Percentage of each type of paper

# %%
numer_type.plot.pie(autopct='%.2f',figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='type'>

# %% [markdown]
# 15- Establish bins for downloads (bins=3)

# %%
df['downloads'].value_counts(bins=3)
# Out:
# (0.976, 8.667]     8
# (8.667, 16.333]    1
# (16.333, 24.0]     1
# Name: downloads, dtype: int64

# %% [markdown]
# 16- Group by author . Perform calculations, total downloads for each group

# %%
df.groupby('author')['downloads'].sum()
# Out:
# author
# Ahmad    25
# Majed     9
# Sami     31
# Name: downloads, dtype: int64

# %% [markdown]
# 17- Sort the dataframe by number of downloads in descending order

# %%
df.sort_values('downloads',ascending=False, inplace=True)
df
# Out:
#   author  impact_factor  downloads        type
# 8   Sami            7.0         24  conference
# 1  Ahmad            3.0         13     journal
# 6  Majed            4.5          7  conference
# 4  Ahmad            5.0          5  conference
# 9   Sami            3.0          4  conference
# 0  Ahmad            2.5          3     journal
# 3   Sami            NaN          3     journal
# 5  Ahmad            2.0          3  conference
# 2  Majed            0.5          2  conference
# 7  Ahmad            NaN          1     journal

# %% [markdown]
# 18-  Check for NaN under only type column:

# %%
df.type.isna()
# Out:
# 8    False
# 1    False
# 6    False
# 4    False
# 9    False
# 0    False
# 3    False
# 5    False
# 2    False
# 7    False
# Name: type, dtype: bool

# %% [markdown]
# 19- replace type the paper to 0 if type is journal and 1 if the type is conference

# %%
df['type'].replace(['journal','conference'],[0,1])
# Out:
# 8    1
# 1    0
# 6    1
# 4    1
# 9    1
# 0    0
# 3    0
# 5    1
# 2    1
# 7    0
# Name: type, dtype: int64

# %% [markdown]
# 20- save the datafrom as csv with name 'hw3.csv'

# %%
df.to_csv('hw3.csv')

# %% [markdown]
# # ----------------------------

# %%
df1 = pd.DataFrame({'letter': list('rrrbbfrrbfffbbf'), 
                   'reads': [123,345,34,1,45,14,4,52,54,23,235,21,57,3,87]})

# %%
df1
# Out:
#    letter  reads
# 0       r    123
# 1       r    345
# 2       r     34
# 3       b      1
# 4       b     45
# 5       f     14
# 6       r      4
# 7       r     52
# 8       b     54
# 9       f     23
# 10      f    235
# 11      f     21
# 12      b     57
# 13      b      3
# 14      f     87

# %% [markdown]
# 21- For each group of letter , find the sum of the three greatest values. (hint: read about nlargest())

# %%
df1.groupby('letter').apply(lambda x: x.reads.nlargest(3).sum())
# Out:
# letter
# b    156
# f    345
# r    520
# dtype: int64

# %%
import numpy as np
df2 = pd.DataFrame(data=np.random.randint(1, 101, size=(20, 4)), columns = ['A', 'B', 'C', 'D'])

# %%
df2
# Out:
#      A    B   C    D
# 0   37   78  21   14
# 1   74    1  52   14
# 2   21    8  72   96
# 3   93   10  60   42
# 4   48   47  11  100
# 5   38    6   9   85
# 6   66   18  11   52
# 7   43   53  70   40
# 8   39   65  20   20
# 9   64   55  38    3
# 10  10   89  32   29
# 11  52   50  59   53
# 12  59   42   2   64
# 13  32    1  27   96
# 14  41   29  65   59
# 15  86  100  59   96
# 16  26   72  35   31
# 17  74   37  43    2
# 18  49   16  76   19
# 19  84   36  63   72

# %% [markdown]
# 22- drop only columns A and C

# %%
df2.drop(columns=['A', 'C'])
# Out:
#       B    D
# 0    78   14
# 1     1   14
# 2     8   96
# 3    10   42
# 4    47  100
# 5     6   85
# 6    18   52
# 7    53   40
# 8    65   20
# 9    55    3
# 10   89   29
# 11   50   53
# 12   42   64
# 13    1   96
# 14   29   59
# 15  100   96
# 16   72   31
# 17   37    2
# 18   16   19
# 19   36   72

# %% [markdown]
# 23- change any value >80 in the dataframe above to NaN

# %%
df2[df2>80]=np.nan
df2
# Out:
#        A     B   C     D
# 0   37.0  78.0  21  14.0
# 1   74.0   1.0  52  14.0
# 2   21.0   8.0  72   NaN
# 3    NaN  10.0  60  42.0
# 4   48.0  47.0  11   NaN
# 5   38.0   6.0   9   NaN
# 6   66.0  18.0  11  52.0
# 7   43.0  53.0  70  40.0
# 8   39.0  65.0  20  20.0
# 9   64.0  55.0  38   3.0
# 10  10.0   NaN  32  29.0
# 11  52.0  50.0  59  53.0
# 12  59.0  42.0   2  64.0
# 13  32.0   1.0  27   NaN
# 14  41.0  29.0  65  59.0
# 15   NaN   NaN  59   NaN
# 16  26.0  72.0  35  31.0
# 17  74.0  37.0  43   2.0
# 18  49.0  16.0  76  19.0
# 19   NaN  36.0  63  72.0

# %%
import numpy as np
df4 = pd.DataFrame(data=np.random.randint(55, 101, size=(30, 1)),columns= ['Grade'])

# %%
df4
# Out:
#     Grade
# 0      85
# 1      69
# 2      94
# 3      71
# 4      78
# 5      69
# 6      88
# 7      77
# 8      73
# 9      99
# 10     88
# 11     85
# 12     91
# 13     99
# 14     62
# 15     98
# 16    100
# 17     94
# 18     64
# 19     96
# 20     86
# 21     85
# 22     78
# 23     81
# 24     72
# 25     58
# 26     92
# 27     72
# 28     82
# 29     70

# %% [markdown]
# 24- Group data using custom function: Let's say you want to group your data using custom function. Here the requirement is to create three groups¶
# - A+  when grades was between 95<=grade<=100
# - A  when grades was between 90<=grade<95
# - B  when grades was between 80<=grade<85
# - C+  when grades was between 75<=grade<80
# - C  when grades was between 70<=grade<75
# - F otherwise

# %%
def group_(df4, idx, col):

    if 95 <= df4[col].loc[idx] <= 100:
        return 'A+'
    elif 90 <= df4[col].loc[idx] < 95:
        return 'A'
    elif 85 <= df4[col].loc[idx] < 90:
        return 'B+'
    elif 80 <= df4[col].loc[idx] < 85:
        return 'B'
    elif 75 <= df4[col].loc[idx] < 80:
        return 'C+'
    elif 70 <= df4[col].loc[idx] < 75:
        return 'C'
    else:
        return 'F'

# %%
g = df4.groupby(lambda idx: group_(df4, idx, 'Grade'))
g

# %%
for k, data in g:
    print("Group by : {}\n".format(k))
    print(data)
# Out:
# Group by : A
#
#     Grade
# 2      94
# 12     91
# 17     94
# 26     92
# Group by : A+
#
#     Grade
# 9      99
# 13     99
# 15     98
# 16    100
# 19     96
# Group by : B
#
#     Grade
# 23     81
# 28     82
# Group by : B+
#
#     Grade
# 0      85
# 6      88
# 10     88
# 11     85
# 20     86
# 21     85
# Group by : C
#
#     Grade
# 3      71
# 8      73
# 24     72
# 27     72
# 29     70
# Group by : C+
#
#     Grade
# 4      78
# 7      77
# 22     78
# Group by : F
#
#     Grade
# 1      69
# 5      69
# 14     62
# 18     64
# 25     58

# %% [markdown]
# # --------------------------------

# %% [markdown]
# 25- Write a Pandas program to merge (left join) the two dataframes using Item from left dataframe only.

# %%
data1 = pd.DataFrame({'Item1': ['K0', 'K0', 'K1', 'K2'],
                     'Item2': ['K0', 'K1', 'K0', 'K1'],
                     'P': ['P0', 'P1', 'P2', 'P3'],
                     'Q': ['Q0', 'Q1', 'Q2', 'Q3']}) 
data2 = pd.DataFrame({'Item1': ['K0', 'K1', 'K1', 'K2'],
                      'Item2': ['K0', 'K0', 'K0', 'K0'],
                      'R': ['R0', 'R1', 'R2', 'R3'],
                      'S': ['S0', 'S1', 'S2', 'S3']})

# %%
result = pd.merge(data1,data2, on='Item1', how='left')
result.head()
# Out:
#   Item1 Item2_x   P   Q Item2_y   R   S
# 0    K0      K0  P0  Q0      K0  R0  S0
# 1    K0      K1  P1  Q1      K0  R0  S0
# 2    K1      K0  P2  Q2      K0  R1  S1
# 3    K1      K0  P2  Q2      K0  R2  S2
# 4    K2      K1  P3  Q3      K0  R3  S3

# %% [markdown]
# 26- Write a Pandas program to merge (left join) the two dataframes using Item1 and Item2 from left dataframe only. (hint: read about 'on' in merge()

# %%
result = pd.merge(data1,data2, on=['Item1','Item2'], how='left')
result.head()
# Out:
#   Item1 Item2   P   Q    R    S
# 0    K0    K0  P0  Q0   R0   S0
# 1    K0    K1  P1  Q1  NaN  NaN
# 2    K1    K0  P2  Q2   R1   S1
# 3    K1    K0  P2  Q2   R2   S2
# 4    K2    K1  P3  Q3  NaN  NaN

# %% [markdown]
# # Part 2

# %% [markdown]
# #### In this part, each student needs to find dataset with extension .csv or xlsx file. Then, load it into a pandas DataFrame to explore it and perform some basic cleaning tasks removing information, replace , drop, etc. You must perform at least 10 tasks that you have learnt.  (Please, provide the url of the dataset location).

# %% [markdown]
# link for the dataset  : https://www.kaggle.com/andrewmvd/heart-failure-clinical-data

# %%
df=pd.read_csv("heart_failure_clinical_records_dataset.csv")
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.head(10)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
# 7  60.0        1                       315         1                 60
# 8  65.0        0                       157         0                 65
# 9  80.0        1                       123         0                 35
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
# 5                    1  204000.00               2.1           132    1
# 6                    0  127000.00               1.2           137    1
# 7                    0  454000.00               1.1           131    1
# 8                    0  263358.03               1.5           138    0
# 9                    1  388000.00               9.4           133    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1
# 5        1     8            1
# 6        0    10            1
# 7        1    10            1
# 8        0    10            1
# 9        1    10            1

# %%
df.drop(columns=['time', 'ejection_fraction','platelets','high_blood_pressure'], inplace=True)
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  serum_creatinine  \
# 0  75.0        0                       582         0               1.9
# 1  55.0        0                      7861         0               1.1
# 2  65.0        0                       146         0               1.3
# 3  50.0        1                       111         0               1.9
# 4  65.0        1                       160         1               2.7
#
#    serum_sodium  sex  smoking  DEATH_EVENT
# 0           130    1        0            1
# 1           136    1        0            1
# 2           129    1        1            1
# 3           137    1        0            1
# 4           116    0        0            1

# %%
df['DEATH_EVENT'].replace([0,1],['die',"live"], inplace=True)
df['sex'].replace([0,1],['female',"male"], inplace=True)
df.head(20)
# Out:
#      age  anaemia  creatinine_phosphokinase  diabetes  serum_creatinine  \
# 0   75.0        0                       582         0               1.9
# 1   55.0        0                      7861         0               1.1
# 2   65.0        0                       146         0               1.3
# 3   50.0        1                       111         0               1.9
# 4   65.0        1                       160         1               2.7
# 5   90.0        1                        47         0               2.1
# 6   75.0        1                       246         0               1.2
# 7   60.0        1                       315         1               1.1
# 8   65.0        0                       157         0               1.5
# 9   80.0        1                       123         0               9.4
# 10  75.0        1                        81         0               4.0
# 11  62.0        0                       231         0               0.9
# 12  45.0        1                       981         0               1.1
# 13  50.0        1                       168         0               1.1
# 14  49.0        1                        80         0               1.0
# 15  82.0        1                       379         0               1.3
# 16  87.0        1                       149         0               0.9
# 17  45.0        0                       582         0               0.8
# 18  70.0        1                       125         0               1.0
# 19  48.0        1                       582         1               1.9
#
#     serum_sodium     sex  smoking DEATH_EVENT
# 0            130    male        0        live
# 1            136    male        0        live
# 2            129    male        1        live
# 3            137    male        0        live
# 4            116  female        0        live
# 5            132    male        1        live
# 6            137    male        0        live
# 7            131    male        1        live
# 8            138  female        0        live
# 9            133    male        1        live
# 10           131    male        1        live
# 11           140    male        1        live
# 12           137    male        0        live
# 13           137    male        0        live
# 14           138  female        0         die
# 15           136    male        0        live
# 16           140    male        0        live
# 17           127    male        0        live
# 18           140  female        0        live
# 19           121  female        0        live

# %%
df.groupby('sex')['sex'].count().plot.pie(autopct='%.2f',figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
df.groupby('sex')['sex'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
df.groupby('DEATH_EVENT')['DEATH_EVENT'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='DEATH_EVENT'>

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# DEATH_EVENT                 0
# dtype: int64

# %%
df.sort_values('age', inplace=True)
df.head(20)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  serum_creatinine  \
# 269  40.0        0                       582         1              1.00
# 232  40.0        1                       129         0              0.90
# 180  40.0        0                       478         1              0.90
# 242  40.0        0                        90         0              1.10
# 248  40.0        0                       624         0              1.00
# 189  40.0        0                       244         0              0.90
# 206  40.0        1                       101         0              0.80
# 70   41.0        0                       148         0              0.80
# 273  42.0        0                        64         0              0.70
# 103  42.0        0                      5209         0              1.00
# 282  42.0        0                        64         0              3.80
# 92   42.0        0                       582         0              1.18
# 222  42.0        1                        86         0              1.10
# 77   42.0        0                       102         1              1.20
# 66   42.0        1                       250         1              1.30
# 125  43.0        1                       358         0              1.30
# 270  44.0        0                       582         1              1.60
# 88   44.0        0                        84         1              0.70
# 201  45.0        0                       308         1              1.00
# 194  45.0        0                       582         0              1.60
#
#      serum_sodium     sex  smoking DEATH_EVENT
# 269           132    male        0         die
# 232           137    male        0         die
# 180           136    male        0         die
# 242           136    male        1         die
# 248           142    male        1         die
# 189           140  female        0         die
# 206           141  female        0         die
# 70            140    male        1         die
# 273           140    male        0         die
# 103           140    male        1         die
# 282           128    male        1         die
# 92            137  female        0         die
# 222           139    male        1         die
# 77            140    male        0         die
# 66            136  female        0        live
# 125           135  female        0         die
# 270           130    male        1         die
# 88            139    male        0         die
# 201           136    male        0         die
# 194           135    male        0        live

# %%
df.to_csv('example.csv',index=False)
